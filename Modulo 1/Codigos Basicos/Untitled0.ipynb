# %% [markdown]
# # Função print()
# A função print() é uma das funções mais importantes e usadas na linguagem python. Sua é basicamente, exibir mensagens na tela ou envia-las para outro dispositivo, como imprimir dentro de um arquivo de texto.
#
# No python 3, print() é uma função interna de modo que não é necessarios

# %%
print("meu primeiro print") # todo texto deve
# Out:
# meu primeiro print

# %%
print("meu segundo print")
# Out:
# meu segundo print

# %%
print(3 + 9)
# Out:
# 12

# %%
print(5 +2)
# Out:
# 7

# %%
nome = "bumbum"
sobrenome =
