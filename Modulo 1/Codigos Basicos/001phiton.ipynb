# %% [markdown]
# #tutorial variaveis

# %% [markdown]
# #o que são variaveis

# %% [markdown]
# Variavel com texto (string)

# %%
nome = "gabriel"
print(nome)
# Out:
# gabriel

# %%
nome = "neymar"
print (nome)
# Out:
# neymar

# %%
nome = tocomfomeeeeeeeeee
print (nome)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-85898219.py in <cell line: 0>()
# ----> 1 nome = tocomfomeeeeeeeeee
#       2 print (nome)
#
# NameError: name 'tocomfomeeeeeeeeee' is not defined

# %% [markdown]
# variavel com numero inteiro (int)

# %% [markdown]
# C

# %%
idade = 16
print(idade)

# %%
# messi
temperatura =
print(temperatura)

# %% [markdown]
# variaveis são espaços na memoria do computador onde podemos guardar informações(como textos, numeros, resultados de aclculos, etc)

# %%
altura = 1.62 # em python os numeros decimais são escritos com ".", exemplo= 5.2
print (altura)
# Out:
# 1.62

# %%
pi = 3.14
print(pi)
# Out:
# 3.14

# %%
estudante  = True
print(estudante)
# Out:
# True

# %% [markdown]
# pode:
#
#
# *  começar com letra
# *  conter número, mas não pode começar
# com número, mas não pode começar com número Exemplo(n1, numero1, etc)
#
# não pode:
# *  começar com número
# *  usar espaço Exemplo(nome

# %% [markdown]
# ## o que é snake_case?
#
# snake_case é um estilo de scrita usado para nome de variaveis, funções, e nomes em geral no codigo. neste estilo, as palavras são todas as minúsculas e separadas por um underline(_)

# %% [markdown]
# se
