# %% [markdown]
# operadores relacionados

# %% [markdown]
# *  > maior igual
# *  >= maior igual
# *  <=menor
# *  <= menor igual
# *  != diferente
# *  == igual

# %%
10 > 20
# Out:
# False

# %%
10 < 20
# Out:
# True

# %%
5+1 != 6
# Out:
# False

# %%
3+1 >= 4
# Out:
# True

# %%
nome_aluno = "patricia"
nome_professor = "flavia"

# %%
nome_aluno == nome_professor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-233084725.py in <cell line: 0>()
# ----> 1 nome_aluno == nome_professor
#
# NameError: name 'nome_aluno' is not defined
