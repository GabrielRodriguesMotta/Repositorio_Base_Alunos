# %% [markdown]
# operadores relacionados

# %% [markdown]
# *  > maior igual
# *  >= maior igual
# *  <=menor
# *  <= menor igual
# *  != diferente
# *  == igual

# %%
10 > 20
# Out:
# False

# %%
10 < 20
# Out:
# True

# %%
5+1 != 6
# Out:
# False

# %%
3+1 >= 4
# Out:
# True

# %%
nome_aluno = "patricia"
nome_professor = "flavia"

# %%
nome_aluno == nome_professor
# Out:
# False

# %%
10 !=

# %% [markdown]
# #operadores logicos
#
# and (E)
# or (OU)
# not (negação)

# %% [markdown]
# # and
#
# true+ true = true
#
# true + false = false
#
# false + true = false
#
# false + false = false

# %%
(10<20) and (20 <30)
# Out:
# True

# %% [markdown]
# # or
#
# true + true = true
#
# true + false = true
#
# false + true = true
#
# false + false = false

# %%
(1 < 2) or (3 > 6)
# Out:
# True

# %% [markdown]
# #not
#
# not true = false not false = true

# %%
not true

# %%
not false
