# %% [markdown]
#  4) crie uma calculadora simples (adição, subtração, mutiplacação e divisão). seu codigo deve receber 2 numeros e apresentar o resultado das 4 operações

# %%
n1= float(input("digite um numero"))

# %%
q = "ola mundo"
print(q)
